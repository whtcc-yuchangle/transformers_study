# %%
import os

os.environ["HF_ENDPOINT"] = "https://hf-mirror.com"

# %%
from transformers import pipeline

qa_pipe = pipeline("question-answering", model="uer/roberta-base-chinese-extractive-qa")
# Out:
# Device set to use cuda:0

# %%
qa_pipe

# %%
from transformers.pipelines.question_answering import QuestionAnsweringPipeline

# %%
result = qa_pipe(question="中国的首都是哪里？", context="中国的首都是北京", max_answer_len=2)
result
# Out:
# Disabling tokenizer parallelism, we're using DataLoader multithreading already
# {'score': 0.7320814728736877, 'start': 6, 'end': 8, 'answer': '北京'}

# %%
result = qa_pipe(question="小明在哪里上班？", context="小明在武汉上班", max_answer_len=2)
result
# Out:
# {'score': 0.902618944644928, 'start': 3, 'end': 5, 'answer': '武汉'}
